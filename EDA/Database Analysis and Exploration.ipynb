# %% [markdown]
# # Beak Data Challenge - Data Analyst
# ## Database exploration and analysis

# %% [markdown]
# ### Setup postgreSQL server and import usefull package

# %%
### This is a terrible approach use only in testing
import sys
sys.path.insert(1, 'G:\\My Drive\\Luis Eduardo Higuera Calderon\\Proyectos\\Beek.io\\Beak Data Challenge\\src')

from apps.visual_backend import DashPlotting
from backend import runQuery

import pandas as pd
import numpy as np
# Out:
# ['G:\\My Drive\\Luis Eduardo Higuera Calderon\\Proyectos\\Beek.io\\Beak Data Challenge\\EDA', 'G:\\My Drive\\Luis Eduardo Higuera Calderon\\Proyectos\\Beek.io\\Beak Data Challenge\\src', 'C:\\Users\\luise\\miniconda3\\envs\\beek\\python39.zip', 'C:\\Users\\luise\\miniconda3\\envs\\beek\\DLLs', 'C:\\Users\\luise\\miniconda3\\envs\\beek\\lib', 'C:\\Users\\luise\\miniconda3\\envs\\beek', '', 'C:\\Users\\luise\\miniconda3\\envs\\beek\\lib\\site-packages', 'C:\\Users\\luise\\miniconda3\\envs\\beek\\lib\\site-packages\\win32', 'C:\\Users\\luise\\miniconda3\\envs\\beek\\lib\\site-packages\\win32\\lib', 'C:\\Users\\luise\\miniconda3\\envs\\beek\\lib\\site-packages\\Pythonwin', 'C:\\Users\\luise\\miniconda3\\envs\\beek\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\luise\\.ipython']

# %% [markdown]
# ## 1. Top Ten

# %% [markdown]
# ### Users

# %%
runQuery("""
SELECT user_id, SUM(seconds) as Total_time
FROM audiobook_plays
GROUP BY user_id
ORDER BY Total_time DESC
LIMIT 10;
""")
# Out:
#    user_id   total_time
# 0   876083  1685061.545
# 1   954745  1295564.176
# 2   829232   920223.793
# 3    53930   901351.575
# 4   967058   823700.546
# 5   980108   751762.359
# 6   844824   670955.438
# 7   958114   604498.961
# 8   527831   601459.086
# 9   910357   594632.452

# %% [markdown]
# ### Audiobooks

# %%
runQuery("""
    SELECT audiobook_id, SUM(seconds) as Total_time
    FROM audiobook_plays
    GROUP BY audiobook_id
    ORDER BY Total_time DESC
    LIMIT 10;
""")
# Out:
#    audiobook_id   total_time
# 0        308346  5025181.050
# 1        238952  4092814.217
# 2        249087  3022995.480
# 3        223467  2483408.005
# 4        223494  2465606.344
# 5        223329  2118576.488
# 6        105720  2118238.976
# 7        243851  1745427.782
# 8        182131  1632881.546
# 9        202942  1492383.766

# %% [markdown]
# ## 2. Weakly Unique Active Users

# %%
runQuery("""
    WITH WAU (year, weekly, user_id) AS (
        SELECT date_part('year', created_at::date)
        , date_part('week', created_at::date)
        , user_id
        FROM audiobook_plays
    )
    SELECT year
        , weekly
        , COUNT(DISTINCT user_id)
    FROM WAU
    GROUP BY year, weekly
    ORDER BY year, weekly
    LIMIT 50;
""")
# Out:
#       year  weekly  count
# 0   2018.0     1.0     68
# 1   2018.0    49.0     11
# 2   2018.0    50.0     36
# 3   2018.0    51.0     86
# 4   2018.0    52.0    161
# 5   2019.0     1.0    167
# 6   2019.0     2.0    235
# 7   2019.0     3.0    544
# 8   2019.0     4.0    663
# 9   2019.0     5.0    557
# 10  2019.0     6.0    454
# 11  2019.0     7.0    458
# 12  2019.0     8.0    371
# 13  2019.0     9.0    316
# 14  2019.0    10.0    325
# 15  2019.0    11.0    355
# 16  2019.0    12.0    400
# 17  2019.0    13.0    348
# 18  2019.0    14.0    392
# 19  2019.0    15.0    261

# %% [markdown]
# ## 3. Week over week retention rate of active users

# %%
runQuery("""
    WITH user_week_date(user_id, 
        current_date_, prev_date) AS (
        SELECT DISTINCT
            abp.user_id
            , cw.current_week
            , (cw.current_week - INTERVAL '7 days')::date
        FROM audiobook_plays abp
            , LATERAL(SELECT DISTINCT abp.user_id, DATE_TRUNC('week',created_at)::date AS current_week) cw
        ORDER BY user_id, cw.current_week
    ),
    user_week_active AS (
        SELECT *
            , LAG(current_date_) OVER(PARTITION BY user_id ORDER BY current_date_) AS last_week
        FROM user_week_date uwa
    ),
    user_retention AS (
        SELECT *
            , prev_date=last_week AS retained
        FROM user_week_active
    ),
    week_over_week AS (
        SELECT current_date_
            , COUNT(1) AS total_users
            , COUNT(CASE WHEN retained THEN 1 END) AS active_users
        FROM user_retention
        GROUP BY current_date_
        ORDER BY current_date_
    )
    SELECT current_date_ AS week
        , total_users
        , active_users
        , ROUND(active_users::numeric/total_users*100, 2) AS retention_rate
    FROM week_over_week;
""")
# Out:
#           week  total_users  active_users retention_rate
# 0   2018-12-03           11             0           0.00
# 1   2018-12-10           36             6          16.67
# 2   2018-12-17           86            13          15.12
# 3   2018-12-24          161            57          35.40
# 4   2018-12-31          186            94          50.54
# 5   2019-01-07          235            83          35.32
# 6   2019-01-14          544           129          23.71
# 7   2019-01-21          663           260          39.22
# 8   2019-01-28          557           290          52.06
# 9   2019-02-04          454           226          49.78
# 10  2019-02-11          458           188          41.05
# 11  2019-02-18          371           200          53.91
# 12  2019-02-25          316           173          54.75
# 13  2019-03-04          325           153          47.08
# 14  2019-03-11          355           169          47.61
# 15  2019-03-18          400           200          50.00
# 16  2019-03-25          348           193          55.46
# 17  2019-04-01          392           182          46.43
# 18  2019-04-08          261           167          63.98

# %% [markdown]
# ## 4. Average time listened last 30 days

# %%
runQuery("""
    SELECT user_id
        , SUM(seconds/3600) AS hours_played --tener en cuenta que preguntan por horas
        , AVG(seconds/3600) AS mean_hours_played --tener en cuenta que preguntan por horas
    FROM audiobook_plays ap
    INNER JOIN users u 
    ON ap.user_id = u.id
    WHERE ap.created_at > u.last_sign_in_at - INTERVAL '30 days'
    GROUP BY user_id
    ORDER BY user_id;
""")
# Out:
#       user_id                 hours_played           mean_hours_played
# 0        2392   8.576727222222222222224444  0.136138527336860670194039
# 1        4461       0.05794666666666666666      0.02897333333333333333
# 2        8427       0.09480194444444444445      0.02370048611111111111
# 3        9511       2.48346694444444444444      0.14608629084967320261
# 4       10520  68.554160833333333344513334  0.155099911387631975892564
# ...       ...                          ...                         ...
# 1962   993510       0.51142833333333333332      0.08523805555555555555
# 1963   993528           1.2491686111111111      1.24916861111111110000
# 1964   993558       1.05020777777777777778      0.35006925925925925926
# 1965   993705       0.09918916666666666667      0.09918916666666666667
# 1966   993707       1.05053027777777777779      0.04202121111111111111
#
# [1967 rows x 3 columns]

# %% [markdown]
# ## 5. Month over month growth audiobook plays (%)

# %%
runQuery("""
    SELECT *
        , ROUND((count_by_month- LAG(count_by_month) OVER())::numeric * 100 / LAG(count_by_month) OVER(), 2) AS month_growth
    FROM (
        SELECT DATE_TRUNC('month', created_at) AS months
            , COUNT(id) AS count_by_month
            --, AS number_plays
        FROM audiobook_plays
        GROUP BY DATE_TRUNC('month', created_at)
        ORDER BY months) AS counts;
""")
# Out:
#       months  count_by_month month_growth
# 0 2018-12-01           11229         None
# 1 2019-01-01           32230       187.02
# 2 2019-02-01           23659       -26.59
# 3 2019-03-01           29823        26.05
# 4 2019-04-01            8705       -70.81

# %% [markdown]
# ### 6. Distribution of users subscribed

# %%
df_subscribed = runQuery("""
    WITH first_time_played(user_id, month_date) AS (
        SELECT DISTINCT ap.user_id
        , DATE_TRUNC('month', FIRST_VALUE(ap.created_at) OVER (PARTITION BY ap.user_id ORDER BY ap.created_at))::date
        FROM audiobook_plays ap
        INNER JOIN users u
        ON ap.user_id = u.id
        AND has_been_subscribed
    )
    SELECT CONCAT(DATE_PART('year', month_date), '-',DATE_PART('month', month_date)) AS month_year
    FROM first_time_played
    ;
    """)
df_subscribed.head()
# Out:
#   month_year
# 0    2018-12
# 1     2019-1
# 2     2019-2
# 3     2019-1
# 4     2019-2

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()

### Ordenar los meses
dist, ax = plt.subplots(figsize = (7,7))
ax = sns.histplot(df_subscribed, x='month_year')
ax.set_ylabel('Users subscribed', fontsize = 15)
ax.set_xlabel('Year - Month', fontsize = 15)
# Out:
# Text(0.5, 0, 'Year - Month')

# %% [markdown]
# ## 7. Favorite book category

# %%
runQuery("""
    WITH books_without_cat AS (
        SELECT id
            , actual_size 
            , grade_level
            , UNNEST(book_category_codes) AS book_category_code
        FROM audiobook
    )
    , books_cat AS (
        SELECT bwc.id
            , actual_size 
            , grade_level
            , book_category_code
            , name
        FROM books_without_cat bwc
        LEFT JOIN book_categories bc
        ON bwc.book_category_code = bc.book_cateogory_code
    )
    SELECT DISTINCT *
    FROM audiobook_plays abp
    INNER JOIN books_cat bc
    ON bc.id = abp.audiobook_id;
""")
# Out:
#             id                 created_at  user_id  audiobook_id  seconds  \
# 0       474656 2018-12-09 00:05:55.712025   877003        249057  446.337
# 1       474657 2018-12-09 00:07:40.623874   877003        249057   98.289
# 2       474658 2018-12-09 00:11:32.009699   877003        249057  186.955
# 3       474659 2018-12-09 01:07:17.111202   877003        249057  279.780
# 4       474660 2018-12-09 01:08:37.949031   877003        249057   17.819
# ...        ...                        ...      ...           ...      ...
# 203678  580417 2019-04-10 23:56:01.975438   991700        223329    0.986
# 203679  580418 2019-04-10 23:56:01.983642   991700        223329  669.732
# 203680  580418 2019-04-10 23:56:01.983642   991700        223329  669.732
# 203681  580418 2019-04-10 23:56:01.983642   991700        223329  669.732
# 203682  580419 2019-04-10 23:57:10.121062   961849        316847  610.206
#
#             id actual_size grade_level book_category_code  \
# 0       249057   187283108       Adult          SEL023000
# 1       249057   187283108       Adult          SEL023000
# 2       249057   187283108       Adult          SEL023000
# 3       249057   187283108       Adult          SEL023000
# 4       249057   187283108       Adult          SEL023000
# ...        ...         ...         ...                ...
# 203678  223329   430700832       Adult          FIC027020
# 203679  223329   430700832       Adult          FIC000000
# 203680  223329   430700832       Adult          FIC027000
# 203681  223329   430700832       Adult          FIC027020
# 203682  316847   239169524       Adult          BUS000000
#
#                                              name
# 0       Self-Help / Personal Growth / Self-Esteem
# 1       Self-Help / Personal Growth / Self-Esteem
# 2       Self-Help / Personal Growth / Self-Esteem
# 3       Self-Help / Personal Growth / Self-Esteem
# 4       Self-Help / Personal Growth / Self-Esteem
# ...                                           ...
# 203678           Fiction / Romance / Contemporary
# 203679                          Fiction / General
# 203680                Fiction / Romance / General
# 203681           Fiction / Romance / Contemporary
# 203682             Business & Economics / General
#
# [203683 rows x 10 columns]

# %%
runQuery("""
    WITH books(book_id, category_1) AS (
        SELECT a.id
            , bc.name
            --, a.book_category_codes[2]
            --, a.book_category_codes[3]
        FROM audiobook a
        INNER JOIN book_categories bc
        ON a.book_category_codes[1]=bc.book_cateogory_code
    ),
    users_subscribed AS (
        SELECT id
        FROM users
        WHERE has_been_subscribed
    )
    SELECT SUM(seconds),
        category_1
    FROM audiobook_plays a
    INNER JOIN books b
    ON a.audiobook_id = b.book_id
    INNER JOIN users_subscribed us
    ON a.user_id = us.id 
    GROUP BY category_1
    ORDER BY SUM(seconds) DESC
    LIMIT 10;
""")
# Out:
#            sum                                         category_1
# 0  6582429.746                   Fiction / Romance / Contemporary
# 1  5047744.469                        Fiction / Romance / General
# 2  4734604.922       Biography & Autobiography / Personal Memoirs
# 3  4574433.808                        Juvenile Nonfiction / Drama
# 4  4269310.992                                  Fiction / General
# 5  3398332.484                                 Fiction / Literary
# 6  3271884.962  Business & Economics / Personal Finance / General
# 7  2306771.739                                  History / General
# 8  2150941.815                         Juvenile Fiction / General
# 9  2043746.256                  Juvenile Fiction / Love & Romance

# %% [markdown]
# ## 8. Book category more popular

# %% [markdown]
# ## 9. Recomend a book

# %% [markdown]
# ## Data Exploration
